# %% [markdown]
# # Company Analysis
# ### Microsoft (MSFT)

# %%
from market_analytics.dashboard import Dashboard

# %%
d = Dashboard(['msft'])
# Out:
# Password: ········

# %% [markdown]
# ### Wikipedia
# - Get Microsoft information from Wikipedia API

# %%
# wiki data dictionary
wiki = d.company.wiki('msft')
wiki.keys()
# Out:
# dict_keys(['title', 'summary', 'url', 'content', 'links'])

# %%
# get summary and show first sentence
summary = wiki['summary']
summary.split('.')[0]
# Out:
# 'Microsoft Corporation () is an American multinational technology company with headquarters in Redmond, Washington'

# %% [markdown]
# ### 5-Year Stock Price

# %%
d.visual.stock_history('msft', '5 year')

# %% [markdown]
# ### Quote Table

# %%
d.company.quote_table('msft','df')
# Out:
#                                                 Value
# Feature
# 1y Target Est                                  228.71
# 52 Week Range                         132.52 - 232.86
# Ask                                     197.76 x 1300
# Avg. Volume                               3.52430e+07
# Beta (5Y Monthly)                                0.89
# Bid                                      197.72 x 800
# Day's Range                           196.38 - 199.40
# EPS (TTM)                                        5.76
# Earnings Date             Oct 21, 2020 - Oct 26, 2020
# Ex-Dividend Date                         Nov 18, 2020
# Forward Dividend & Yield                 2.24 (1.12%)
# Market Cap                                     1.528T
# Open                                           197.19
# PE Ratio (TTM)                                  34.61
# Previous Close                                 200.39
# Quote Price                                    199.36
# ...

# %% [markdown]
# ### Gross Profit

# %%
d.visual.plot_income_statement('msft','Gross Profit')

# %% [markdown]
# ### Cashflow

# %%
d.company.cashflow('msft', 'df')
# Out:
#                      Breakdown        ttm  6/30/2020  6/30/2019  6/30/2018  \
# 0          Operating Cash Flow   60675000   60675000   52185000   43884000
# 1          Investing Cash Flow  -12223000  -12223000  -15773000   -6061000
# 2          Financing Cash Flow  -46031000  -46031000  -36887000  -33590000
# 3            End Cash Position   13576000   13576000   11356000   11946000
# 4          Capital Expenditure  -15441000  -15441000  -13925000  -11632000
# 5    Issuance of Capital Stock    1343000    1343000    1142000    1002000
# 6             Issuance of Debt          0          0          0    7183000
# 7            Repayment of Debt   -5518000   -5518000   -4000000  -10060000
# 8  Repurchase of Capital Stock  -22968000  -22968000  -19543000  -10721000
# 9               Free Cash Flow   45234000   45234000   38260000   32252000
#
#    6/30/2017
# 0   39507000
# 1  -46781000
# 2    8408000
# 3    7663000
# 4   -8129000
# 5     772000
# 6   44344000
# 7   -7922000
# ...

# %%
plot_cashflow('msft', 'Financing Cash Flow')

# %% [markdown]
# ### Yearly Balance Sheet

# %%
d.company.yearly_balance_sheet('msft', 'df')
# Out:
#                                   Breakdown  6/30/2020  6/30/2019  6/30/2018  \
# 0                              Total Assets  301311000  286556000  258848000
# 1   Total Liabilities Net Minority Interest  183007000  184226000  176130000
# 2      Total Equity Gross Minority Interest  118304000  102330000   82718000
# 3                      Total Capitalization  177882000  168992000  154960000
# 4                       Common Stock Equity  118304000  102330000   82718000
# 5                 Capital Lease Obligations    7671000    6188000    5568000
# 6                       Net Tangible Assets   67915000   52554000   38982000
# 7                           Working Capital  109605000  106132000  111174000
# 8                          Invested Capital  181631000  174508000  158958000
# 9                       Tangible Book Value   67915000   52554000   38982000
# 10                               Total Debt   70998000   78366000   81808000
# ...

# %% [markdown]
# ### Stats

# %%
d.company.stats('msft','df')
# Out:
#                                          Attribute         Value
# 0                                Beta (5Y Monthly)          0.89
# 1                                 52-Week Change 3        44.02%
# 2                          S&P500 52-Week Change 3        10.95%
# 3                                   52 Week High 3        232.86
# 4                                    52 Week Low 3        132.52
# 5                          50-Day Moving Average 3        212.88
# 6                         200-Day Moving Average 3        188.97
# 7                              Avg Vol (3 month) 3        35.24M
# 8                               Avg Vol (10 day) 3        33.56M
# 9                             Shares Outstanding 5         7.57B
# 10                                           Float         7.46B
# 11                            % Held by Insiders 1         1.42%
# 12                        % Held by Institutions 1        74.09%
# ...
