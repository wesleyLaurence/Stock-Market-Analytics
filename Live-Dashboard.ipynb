# %% [markdown]
# # Live Stock Dashboard

# %%
from StockMarket import Stock_Model
import matplotlib.pyplot as plt
import pandas as pd

# animation settings
# %matplotlib notebook
plt.rcParams["animation.html"] = "jshtml"

# %%
sm = Stock_Model()
# Out:
# Password: ········

# %%
sm.live_data('MSFT', time_filter=-50)
# Out:
# <img src="data:image/png;base64,..." width="1200">
